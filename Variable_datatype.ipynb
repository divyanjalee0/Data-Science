# %%
name = "Alice"
age = 25
is_student = True

# %%
# str to int
x = int("10")      # 10

# int to str
y = str(25)        # "25"

# float to int
z = int(3.9)       # 3 (truncates, not rounds)

# list from string
lst = list("abc")  # ['a', 'b', 'c']

# %%
print("hello")  # ValueError
# Out:
# hello
